# %%
# TensorFlow and tf.keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#os.listdir(dir)

# %%
#cv2.imread(dir_waldo + os.listdir(dir_waldo)[0])

# %%
path = '/content/drive/Shareddrives/Project_4_Waldo/data/'

# %%
waldo_img = path + 'Hey-Waldo/64/waldo/'

# %%
notwaldo_img = path + 'Hey-Waldo/64/notwaldo/'

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
annot = path  + "Hey-Waldo/waldo_annotations/"

# %%
original_img = path  + 'Hey-Waldo/original-images/'

# %%
image_a = cv2.imread("/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/original-images/waldo_annotations/waldo_1.png.csv")
#image_a = cv2.cvtColor(image_a, cv2.COLOR_BGR2RGB)

# %%
print(image_a)
# Out:
# None

# %%
image_in = cv2.imread("/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/original-images/1.jpg")
image_in = cv2.cvtColor(image_in, cv2.COLOR_BGR2RGB)

# %%
print(image_in)
# Out:
# [[[255 228  34]
#   [254 224  28]
#   [249 222  19]
#   ...
#   [121  92  84]
#   [ 79  59  68]
#   [ 15   3  17]]
#
#  [[255 232  67]
#   [236 213  37]
#   [255 238  42]
#   ...
#   [ 23   7   7]
#   [ 11   3  16]
#   [  7   3  20]]
#
#  [[ 82  70   0]
#   [238 224  89]
#   [251 235  52]
#   ...
#   [  9  18  33]
#   [ 10  21  43]
#   [  7  17  44]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 252]
#   [253 255 250]
#   ...
#   [253 255 254]
#   [253 255 254]
#   [251 255 252]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 252]
#   [254 254 252]
#   [254 254 252]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 252]
#   [255 255 253]
#   [255 255 253]]]

# %%
print(os.listdir(original_img))
# Out:
# ['1.jpg', '6.jpg', '2.jpg', '5.jpg', '7.jpg', '4.jpg', '12.jpg', '17.jpg', '18.jpg', '8.jpg', '16.jpg', '19.jpg', '14.jpg', '13.jpg', '11.jpg', '9.jpg', '10.jpg', '15.jpg', '3.jpg']

# %%
print(os.listdir(annot))
# Out:
# ['waldo_3.png', 'waldo_4.png', 'waldo_2.png', 'waldo_5.png', 'waldo_6.png', 'waldo_7.png', 'waldo_8.png', 'waldo_9.png', 'waldo_11.png', 'waldo_12.png', 'waldo_13.png', 'waldo_14.png', 'waldo_15.png', 'waldo_16.png', 'waldo_17.png', 'waldo_19.png', 'waldo_18.png', 'waldo_2.png.csv', 'waldo_3.png.csv', 'waldo_4.png.csv', 'waldo_5.png.csv', 'waldo_6.png.csv', 'waldo_7.png.csv', 'waldo_9.png.csv', 'waldo_8.png.csv', 'waldo_10.png.csv', 'waldo_13.png.csv', 'waldo_12.png.csv', 'waldo_11.png.csv', 'waldo_15.png.csv', 'waldo_14.png.csv', 'waldo_16.png.csv', 'waldo_17.png.csv', 'waldo_18.png.csv', 'waldo_19.png.csv', 'waldo_1.png.csv', 'waldo_10.png', 'waldo_10.csv', 'waldo_1.png', 'waldo_1.png.gsheet']

# %%
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
import cv2

# %%
for e,i in enumerate(os.listdir(original_img)):
    if e < 20:
        filename = i.split(".")[0]+".jpg"
        Index = e+1
        filename2 = "waldo_"+str(Index)+".png.csv"
        img = cv2.imread(os.path.join(original_img,filename))
        df = pd.read_csv(os.path.join(annot,filename2))
        plt.imshow(img) 
        for row in df.iterrows():
            x1 = int(''.join(filter(str.isdigit, row[1][8].split(" ")[0])))
            y1 = int(''.join(filter(str.isdigit, row[1][8].split(" ")[1])))
            x2 = int(''.join(filter(str.isdigit, row[1][8].split(" ")[2])))
            y2 = int(''.join(filter(str.isdigit, row[1][8].split(" ")[1])))
            cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,0), 2)
        plt.figure()
        plt.imshow(img)
        break

# %%
print(y2, y1)
# Out:
# 254 254

# %%
print(row[1][3].split(" ")[0])
# Out:
# [254,

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7f08fa7dbb50>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1250, step=1)

# %%
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
im = cv2.imread(os.path.join(original_img,'9.jpg'))
#cv2.imread(os.path.join(annot,"9.jpg"))
ss.setBaseImage(im)
ss.switchToSelectiveSearchFast()
rects = ss.process()
imOut = im.copy()
for i, rect in (enumerate(rects)):
    x, y, w, h = rect
    cv2.rectangle(imOut, (x, y), (x+w, y+h), (255, 0, 0), 1, cv2.LINE_AA)
    print(imOut)
plt.imshow(imOut)
# Out:
# Streaming output truncated to the last 5000 lines.
#   [226 226 226]
#   [226 226 226]]]
# [[[243 244 242]
#   [  0   1   0]
#   [ 36  34  34]
#   ...
#   [228 228 228]
#   [227 227 227]
#   [229 229 229]]
#
#  [[243 244 242]
#   [  0   1   0]
#   [ 43  41  41]
#   ...
#   [236 146 146]
#   [228 228 228]
#   [229 229 229]]
#
#  [[247 245 244]
#   [246   1   0]
#   [254   1   1]
#   ...
#   [254   1   1]
#   [246  87  87]
#   [229 229 229]]
#
#  ...
#
#  [[246 244 243]
#   [232  12  11]
#   [254   1   1]
#   ...
#   [254   1   1]
#   [233 127 127]
#   [227 225 225]]
#
#  [[244 242 241]
#   [ 80  78  77]
#   [ 92  30  30]
#   ...
#   [247   7   7]
#   [227 225 225]
#   [227 225 225]]
#
#  [[245 243 242]
#   [ 97  95  94]
#   [ 20  20  20]
#   ...
#   [225 225 225]
#   [226 226 226]
#   [226 226 226]]]
# [[[243 244 242]
#   [  0   1   0]
#   [ 36  34  34]
#   ...
#   [228 228 228]
#   [227 227 227]
#   [229 229 229]]
#
#  [[243 244 242]
#   [  0   1   0]
#   [ 43  41  41]
#   ...
# ...

# %%
def get_iou(bb1, bb2):
    # assert bb1['x1'] <= bb1['x2']
    # assert bb1['y1'] <= bb1['y2']
    # assert bb2['x1'] <= bb2['x2']
    # assert bb2['y1'] <= bb2['y2']
    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
train_images1 = []
train_labels1 = []

# %%
# print(os.listdir(original_img))
e = 0
i = os.listdir(original_img)[e]
print(e)
filename = i.split(".")[0]+".jpg"
print( filename)
image = cv2.imread(os.path.join(original_img,filename))
filename2 =  "waldo_"+i.split(".")[0]+".png.csv"
print(filename2)
df = pd.read_csv(os.path.join(annot,filename2))
# Out:
# 0
# 1.jpg
# waldo_1.png.csv

# %%
train_images=[]
train_labels=[]

# %%
results = []
for e,i in enumerate(os.listdir(original_img)):
            filename = i.split(".")[0]+".jpg"
            print(e, filename)
            image = cv2.imread(os.path.join(original_img,filename))
            filename2 =  "waldo_"+i.split(".")[0]+".png.csv"
            df = pd.read_csv(os.path.join(annot,filename2))
            gtvalues=[]                 
            for row in df.iterrows():
                x1 = int(''.join(filter(str.isdigit, row[1][0].split(" ")[0])))
                y1 = int(''.join(filter(str.isdigit, row[1][2].split(" ")[0])))
                x2 = int(''.join(filter(str.isdigit, row[1][2].split(" ")[0])))
                y2 = int(''.join(filter(str.isdigit, row[1][4].split(" ")[0])))
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
            print(gtvalues)
            ss.setBaseImage(image)
            ss.switchToSelectiveSearchFast()
            ssresults = ss.process()
            imout = image.copy()
            print(imout)
            counter = 0
            falsecounter = 0
            flag = 0
            fflag = 0
            bflag = 0
            print(ssresults)
            results.append(ssresults)
            train_images=[]
            train_labels=[]
            for e,result in enumerate(ssresults):
                if e < 2000 and flag == 0:
                    for gtval in gtvalues:
                        x,y,w,h = result
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                        if iou > 0.70:
                          timage = imout[y:y+h,x:x+w]
                          resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                          train_images.append(resized)
                          train_labels.append(1)
                          counter += 1
                        else:
                          fflag = 1
                        if iou < 0.3:
                          timage = imout[y:y+h,x:x+w]
                          resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                          train_images.append(resized)
                          train_labels.append(0)
                          falsecounter += 1
                        else :
                            bflag = 1
                    # if fflag == 1 and bflag == 1:
                    #     print("inside")
                    #     flag = 1
# Out:
# 0 1.jpg
# ...

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6459d04d738f> in <module>()
# ----> 1 print(result)
#
# NameError: name 'result' is not defined

# %%
print(train_images)
print(train_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b56e2f91f186> in <module>()
# ----> 1 print(train_images)
#       2 print(train_labels)
#
# NameError: name 'train_images' is not defined

# %%
import keras
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Activation
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
#from keras.optimizers import Adam
from keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=True)
# Out:
# ...
# 553476096/553467096 [==============================] - 3s 0us/step

# %%
# for layers in (vggmodel.layers)[:15]:
#     print(layers)
#     layers.trainable = False
# X= Dense(1000)(vggmodel.layers[-2].output)
# Predictions = Activation('softmax')(X)
# model_final = Model(vggmodel.input, Predictions)
# opt = Adam(lr=0.0001)
# model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])
# model_final.summary()

# %%
for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False
X= vggmodel.layers[-2].output
predictions = Dense(2, activation="softmax")(X)
model_final = Model(vggmodel.input, predictions)
opt = Adam(lr=0.0001)
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])
model_final.summary()
# Out:
# ...
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)
X_new.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8902b8dde63e> in <module>()
# ----> 1 X_new = np.array(train_images)
#       2 y_new = np.array(train_labels)
#       3 X_new.shape
#
# NameError: name 'np' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)
