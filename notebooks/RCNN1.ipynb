# %%
# TensorFlow and tf.keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#dir = '/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/original-images/'
#categories = ['waldo', 'not waldo']

# %%
#os.listdir(dir)

# %%
#cv2.imread(dir_waldo + os.listdir(dir_waldo)[0])

# %%
dir = '/content/drive/Shareddrives/Project_4_Waldo/data/Hey-Waldo/'

# %%
original_img = dir + 'original-images/'

# %%
waldo_img = dir + '64/waldo/'

# %%
notwaldo_img = dir + '64/notwaldo/'

# %%
path = dir

# %%
from google.colab.patches import cv2_imshow

# %%
# img = cv2.imread(os.path.join(original_img,'1.jpg')) 
# #img=cv2.imread(original_img  + os.listdir(original_img )[0])
# #Make copy of the image

# imageLine = img.copy()

# # Draw the image from point A to B

# pointA = (250,100)

# pointB = (250,100)

# cv2.line(imageLine, pointA, pointB, (255, 255, 0), thickness=3)
# cv2_imshow(imageLine)

# cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'1.jpg')) 
imageRectangle = img.copy()
# define the starting and end points of the rectangle
start_point =(700,500)
end_point =(760,600)
# draw the rectangle
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)

# display the output
plt.figure(figsize=[20,20])
plt.imshow(imageRectangle)
plt.savefig('waldo_annotations/waldo_1.png')
cv2.waitKey(0)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img = cv2.imread(os.path.join(original_img,'2.jpg')) 
imageRectangle = img.copy()
# define the starting and end points of the rectangle
start_point =(70,510)
end_point =(120,580)
# draw the rectangle
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
# display the output
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_2.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'3.jpg')) 
imageRectangle = img.copy()
# define the starting and end points of the rectangle
start_point =(1380,450)
end_point =(1440,510)
# draw the rectangle
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
# display the output
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_3.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'4.jpg')) 
imageRectangle = img.copy()
start_point =(1480,270)
end_point =(1520,320)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_4.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'5.jpg')) 
imageRectangle = img.copy()
start_point =(1570,590)
end_point =(1630,660)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_5.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'6.jpg')) 
imageRectangle = img.copy()
start_point =(1710,400)
end_point =(1760,470)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_6.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'7.jpg')) 
imageRectangle = img.copy()
start_point =(785,940)
end_point =(890,1050)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_7.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'8.jpg')) 
imageRectangle = img.copy()
start_point =(1150,270)
end_point =(1200,340)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_8.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'9.jpg')) 
imageRectangle = img.copy()
start_point =(220,720)
end_point =(280,770)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 6, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_9.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'10.jpg')) 
imageRectangle = img.copy()
start_point =(700,150)
end_point =(750,200)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_10.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'11.jpg')) 
imageRectangle = img.copy()
start_point =(450,1520)
end_point =(500,1570)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_11.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'12.jpg')) 
imageRectangle = img.copy()
start_point =(830,510)
end_point =(880,580)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_12.png')
cv2.waitKey(0)

# %%
img2 = cv2.imread(os.path.join(original_img,'13.jpg')) 
imageRectangle = img2.copy()
start_point =(915,260)
end_point =(950,310)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_13.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'14.jpg')) 
imageRectangle = img.copy()
start_point =(180,1860)
end_point =(245,1950)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_14.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'15.jpg')) 
imageRectangle = img.copy()
start_point =(290,420)
end_point =(330,470)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_15.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'16.jpg')) 
imageRectangle = img.copy()
start_point =(1920,750)
end_point =(1970,800)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_16.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'17.jpg')) 
imageRectangle = img.copy()
start_point =(740,240)
end_point =(790,310)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_17.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'18.jpg')) 
imageRectangle = img.copy()
start_point =(1260,70)
end_point =(1300,120)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
#plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_18.png')
cv2.waitKey(0)

# %%
img = cv2.imread(os.path.join(original_img,'19.jpg')) 
imageRectangle = img.copy()
start_point =(320,615)
end_point =(360,660)
cv2.rectangle(imageRectangle, start_point, end_point, (255, 0, 0), thickness= 5, lineType=cv2.LINE_8)
plt.figure(figsize=[20,20])
plt.imshow( imageRectangle)
plt.savefig('waldo_annotations/waldo_19.png')
cv2.waitKey(0)

# %%
cv2.imread(original_img  + os.listdir(original_img )[0])

# %%
img_notwaldo = []
for image in os.listdir(notwaldo_img):
    img_notwaldo.append(cv2.imread(notwaldo_img + image))

# %%
print(img_notwaldo[0])

# %%
img_waldo = []
for image in os.listdir(waldo_img):
    img_waldo.append(cv2.imread(waldo_img + image))

# %%
original_images = []
for image in os.listdir(original_img):
    image_id =  original_img + image
    original_images.append(cv2.imread(original_img + image))

# %%
original_images[0][0]
# Out:
# array([[ 34, 228, 255],
#        [ 28, 224, 254],
#        [ 19, 222, 249],
#        ...,
#        [ 84,  92, 121],
#        [ 68,  59,  79],
#        [ 17,   3,  15]], dtype=uint8)

# %%
#Split the list from starting index upto middle index in first half
first_half= original_images[:9]
#Split the list from middle index index upto the last index in second half
sec_half= original_images[9:]

# %%
print(len(first_half))
print(len(sec_half))
# Out:
# 9
# 10

# %%
import random
random.shuffle(first_half)
random.shuffle(sec_half)

# %%
first_half[1]

# %%
plt.figure(figsize = (15,15))
plt.imshow(first_half[1])

# %%
from PIL import Image

# %%
imgs = []
for x in range(1,20):
  imgs.append(np.array(Image.open(f"waldo_annotations/waldo_{x}.png")))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-165-9e701d3170eb> in <module>()
#       1 imgs = []
#       2 for x in range(1,20):
# ----> 3   imgs.append(np.array(Image.open(f"waldo_annotations/waldo_{x}.png")))
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'waldo_annotations/waldo_1.png'

# %%
import csv

def csvWriter(fil_name, nparray):
  example = nparray.tolist()
  with open(fil_name+'.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerows(example)

#svWriter("waldo_1", img)

# %%
for e, img in enumerate(imgs):
  csvWriter(f"waldo_annotations/waldo_{e+1}.png", img)

# %%
# csvWriter("waldo_annotations/waldo_2", img2)
# csvWriter("waldo_annotations/waldo_3", img3)
# csvWriter("waldo_annotations/waldo_4", img4)
# csvWriter("waldo_annotations/waldo_5", img5)
# csvWriter("waldo_annotations/waldo_6", img6)
# csvWriter("waldo_annotations/waldo_7", img7)
# csvWriter("waldo_annotations/waldo_8", img8)
# csvWriter("waldo_annotations/waldo_9", img9)
# csvWriter("waldo_annotations/waldo_10", img10)
# csvWriter("waldo_annotations/waldo_11", img11)
# csvWriter("waldo_annotations/waldo_12", img12)
# csvWriter("waldo_annotations/waldo_13", img13)
# csvWriter("waldo_annotations/waldo_14", img14)
# csvWriter("waldo_annotations/waldo_15", img15)
# csvWriter("waldo_annotations/waldo_16", img16)
# csvWriter("waldo_annotations/waldo_17", img17)
# csvWriter("waldo_annotations/waldo_18", img18)
# csvWriter("waldo_annotations/waldo_19", img19)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-48806b2b1b89> in <module>()
# ----> 1 csvWriter("waldo_annotations/waldo_2", img2)
#       2 csvWriter("waldo_annotations/waldo_3", img3)
#       3 csvWriter("waldo_annotations/waldo_4", img4)
#       4 csvWriter("waldo_annotations/waldo_5", img5)
#       5 csvWriter("waldo_annotations/waldo_6", img6)
#
# <ipython-input-157-ab864cd4e45e> in csvWriter(fil_name, nparray)
#       2
#       3 def csvWriter(fil_name, nparray):
# ----> 4   example = nparray.tolist()
#       5   with open(fil_name+'.csv', 'w', newline='') as csvfile:
#       6     writer = csv.writer(csvfile, delimiter=',')
#
# KeyboardInterrupt:

# %%
import zipfile

# %%
list_files = ['waldo_annotations/waldo_1.csv', 'waldo_annotations/waldo_2.csv', 'waldo_annotations/waldo_3.csv', 'waldo_annotations/waldo_4.csv', 'waldo_annotations/waldo_5.csv', 'waldo_annotations/waldo_6.csv',
'waldo_annotations/waldo_7.csv', 'waldo_annotations/waldo_8.csv', 'waldo_annotations/waldo_9.csv', 'waldo_annotations/waldo_10.csv', 'waldo_annotations/waldo_11.csv', 'waldo_annotations/waldo_12.csv', 
'waldo_annotations/waldo_13.csv', 'waldo_annotations/waldo_14.csv', 'waldo_annotations/waldo_15.csv', 'waldo_annotations/waldo_16.csv', 'waldo_annotations/waldo_17.csv', 'waldo_annotations/waldo_18.csv',
'waldo_annotations/waldo_19.csv',]

list_files_cooler = []
for x in range(1, 20):
  list_files_cooler.append(f"waldo_annotations/waldo_{x}.csv")

with zipfile.ZipFile('waldo_annotations.zip', 'w') as zipF:
    for file in list_files:
        zipF.write(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-d39cabd79026> in <module>()
#       7 with zipfile.ZipFile('waldo_annotations.zip', 'w') as zipF:
#       8     for file in list_files:
# ----> 9         zipF.write(waldo_annotations/+file)
#
# NameError: name 'waldo_annotations' is not defined

# %% [markdown]
# # Loading manually labelled train-val data

# %%
train_dir = random.shuffle(first_half)
val_dir =random.shuffle(sec_half)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f99f6d7d9505> in <module>()
# ----> 1 train_dir =  random.shuffle(first_half)
#       2 val_dir =random.shuffle(sec_half)
#
# NameError: name 'random' is not defined

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
input_value = [[
    [[1], [2], [4], [4]],
    [[3], [4], [1], [2]],
    [[6], [2], [1], [7]],
    [[1], [3], [2], [8]]
]]
input_value = np.asarray(input_value, dtype='float32')

# %%
rois_value = [
    [0, 0, 0, 1, 3],
    [0, 2, 2, 3, 3],
    [0, 1, 0, 3, 2]
]
rois_value = np.asarray(rois_value, dtype='int32')

# %%
train_images=[]
train_labels=[]

# %%
#fashion_mnist = tf.keras.datasets.fashion_mnist

#(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
